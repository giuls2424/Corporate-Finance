# %%
## Connect to the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Load the necessary packages and libraries
import numpy as np
from scipy.stats import norm

# %% [markdown]
# ## Black-Sholes Model Option Pricing

# %% [markdown]
# In this section, a Black-Scholes model is implemented to price our options. All of them, divided by phase, are given as input to the black_scholes_call_option_pricing function together with its classical inputs. Following the parallelism beetween the financial and real option, we passed the function the value of the underlying asset, in this case the NPV of the project (drug), the strike price (the costs required to develop the project), time to maturity, the risk-free rate and the volatility parameter.

# %%
#################################################################################
#                                                                               #
#                                   VARIABLES                                   #
#                                                                               #
#################################################################################

## S: value of the underlying asset
## K: strike price
## T: time to expiration
## r: risk-free rate
## sigma: volatility


# Define the BS model
def black_scholes_call_option_pricing(S, K, T, r, sigma):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    call_option_price = S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    return call_option_price


# Parameters for drug portfolio 1
drugs_phase1= [
    {'S': 422.87, 'K': 111.55, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 422.87, 'K': 111.55, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 133.51, 'K': 35.22, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 102.14, 'K': 26.95, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 133.51, 'K': 35.22, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 164.72, 'K': 43.45, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 445.91, 'K': 117.63, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 184.82, 'K': 48.76, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 599.05, 'K': 158.03, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 445.91, 'K': 117.63, 'T': 10, 'r': 0.03879, 'sigma': 0.2483}
]


# Calculate call option value for each drug using the model
print("\n")
print("Phase 1")
for i, drug in enumerate(drugs_phase1):
    call_option_price = black_scholes_call_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma'])
    print(f"Black-Scholes Call Option Price for Drug {i + 1}: ${call_option_price:.2f}")

#################################################################################
# Parameters for drug portfolio 2
drugs_phase2= [
    {'S': 244.12, 'K': 59.89, 'T': 10, 'r': 0.0387, 'sigma': 0.125},
    {'S': 114.96, 'K': 27.31, 'T': 10, 'r': 0.0387, 'sigma': 0.15},
    {'S': 263.24, 'K': 62.54, 'T': 10, 'r': 0.0387, 'sigma': 0.125},
    {'S': 259.00, 'K': 61.53, 'T': 10, 'r': 0.0387, 'sigma': 0.125},
    {'S': 302.21, 'K': 71.80, 'T': 10, 'r': 0.0387, 'sigma': 0.175},
    {'S': 302.21, 'K': 71.80, 'T': 10, 'r': 0.0387, 'sigma': 0.175},
    {'S': 208.34, 'K': 49.50, 'T': 10, 'r': 0.0387, 'sigma': 0.2483}]

# Calculate call option value for each drug using the model
print("\n")
print("Phase 2")
for i, drug in enumerate(drugs_phase2):
    call_option_price = black_scholes_call_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma']
    )

    print(f"Black-Scholes Call Option Price for Drug {i + 1}: ${call_option_price:.2f}")

#################################################################################
# Parameters for drug portfolio 3
drugs_phase3= [
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.2483},
    {'S': 3939.82, 'K': 44.18, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 1040.76, 'K': 11.67, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 437.45, 'K': 4.90, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 2053.78, 'K': 23.03, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 1721.95, 'K': 19.31, 'T': 10, 'r': 0.03879, 'sigma': 0.2483}]


# Calculate call option value for each drug using the model
print("\n")
print("Phase 3")
for i, drug in enumerate(drugs_phase3):
    call_option_price = black_scholes_call_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma']
    )
    print(f"Black-Scholes Call Option Price for Drug {i + 1}: ${call_option_price:.2f}")

#################################################################################
# Parameters for drug portfolio 4
print("\n")
print("Phase 4")
drugs_phase4= [
    {'S': 141.88, 'K': 0.31, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 2328.62, 'K': 5.07, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 1659.55, 'K': 3.62 ,'T': 10, 'r': 0.03879, 'sigma': 0.15}]

# Calculate call option value for each drug using the model
for i, drug in enumerate(drugs_phase4):
    call_option_price = black_scholes_call_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma']
    )
    print(f"Black-Scholes Call Option Price for Drug {i + 1}: ${call_option_price:.2f}")
# Out:
# Phase 1
# Black-Scholes Call Option Price for Drug 1: $347.21
# Black-Scholes Call Option Price for Drug 2: $347.21
# Black-Scholes Call Option Price for Drug 3: $109.61
# Black-Scholes Call Option Price for Drug 4: $83.85
# Black-Scholes Call Option Price for Drug 5: $109.61
# Black-Scholes Call Option Price for Drug 6: $135.25
# Black-Scholes Call Option Price for Drug 7: $366.13
# Black-Scholes Call Option Price for Drug 8: $151.75
# Black-Scholes Call Option Price for Drug 9: $491.86
# Black-Scholes Call Option Price for Drug 10: $366.80
#
#
# Phase 2
# Black-Scholes Call Option Price for Drug 1: $203.45
# Black-Scholes Call Option Price for Drug 2: $96.41
# Black-Scholes Call Option Price for Drug 3: $220.77
# Black-Scholes Call Option Price for Drug 4: $217.22
# Black-Scholes Call Option Price for Drug 5: $253.46
# Black-Scholes Call Option Price for Drug 6: $253.46
# Black-Scholes Call Option Price for Drug 7: $174.94
#
#
# Phase 3
# Black-Scholes Call Option Price for Drug 1: $4122.83
# Black-Scholes Call Option Price for Drug 2: $4122.83
# Black-Scholes Call Option Price for Drug 3: $4122.83
# Black-Scholes Call Option Price for Drug 4: $3909.84
# Black-Scholes Call Option Price for Drug 5: $1032.84
# Black-Scholes Call Option Price for Drug 6: $434.13
# Black-Scholes Call Option Price for Drug 7: $4122.83
# Black-Scholes Call Option Price for Drug 8: $2038.15
# Black-Scholes Call Option Price for Drug 9: $4122.83
# Black-Scholes Call Option Price for Drug 10: $1708.85
#
#
# Phase 4
# Black-Scholes Call Option Price for Drug 1: $141.67
# Black-Scholes Call Option Price for Drug 2: $2325.18
# Black-Scholes Call Option Price for Drug 3: $1657.09

# %% [markdown]
# ## Binomial Model for Option Pricing

# %%
def binomial_option_pricing(S, K, T, r, sigma, n, option_type='call'):
    dt = T / n
    u = np.exp(sigma * np.sqrt(dt))
    d = 1 / u

    # Calculate risk-neutral probabilities
    p = (np.exp(r * dt) - d) / (u - d)
    q = 1 - p

    # Construct the binomial tree
    option_values = np.zeros((n + 1, n + 1))
    for i in range(n + 1):
        option_values[n, i] = max(0, payoff(S * u**i * d**(n - i), K, option_type))

    for j in range(n - 1, -1, -1):
        for i in range(j + 1):
            option_values[j, i] = np.exp(-r * dt) * (p * option_values[j + 1, i + 1] + q * option_values[j + 1, i])

    return option_values[0, 0]

def payoff(stock_price, strike_price, option_type):
    if option_type == 'call':
        return max(stock_price - strike_price, 0)
    elif option_type == 'put':
        return max(strike_price - stock_price, 0)
    else:
        raise ValueError("Invalid option type. Use 'call' or 'put'.")

# Parameters for drug portfolio 1
drugs_phase1= [
    {'S': 422.87, 'K': 111.55, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 422.87, 'K': 111.55, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 133.51, 'K': 35.22, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 102.14, 'K': 26.95, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 133.51, 'K': 35.22, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 164.72, 'K': 43.45, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 445.91, 'K': 117.63, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 184.82, 'K': 48.76, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 599.05, 'K': 158.03, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 445.91, 'K': 117.63, 'T': 10, 'r': 0.03879, 'sigma': 0.2483}
]


n = 1000

# Calculate binomial option price for each drug
#option_prices = [binomial_option_pricing(drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma'], n) for drug in drugs]


print("\n")
print("Phase 1")
for i, drug in enumerate(drugs_phase1):
    call_option_price = binomial_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma'], n
    )

    print(f"Binomial price for Drug: {i + 1}: ${call_option_price:.2f}")


#################################################################################
# Parameters for drug portfolio 2
drugs_phase2= [
    {'S': 244.12, 'K': 59.89, 'T': 10, 'r': 0.0387, 'sigma': 0.125},
    {'S': 114.96, 'K': 27.31, 'T': 10, 'r': 0.0387, 'sigma': 0.15},
    {'S': 263.24, 'K': 62.54, 'T': 10, 'r': 0.0387, 'sigma': 0.125},
    {'S': 259.00, 'K': 61.53, 'T': 10, 'r': 0.0387, 'sigma': 0.125},
    {'S': 302.21, 'K': 71.80, 'T': 10, 'r': 0.0387, 'sigma': 0.175},
    {'S': 302.21, 'K': 71.80, 'T': 10, 'r': 0.0387, 'sigma': 0.175},
    {'S': 208.34, 'K': 49.50, 'T': 10, 'r': 0.0387, 'sigma': 0.2483}]

# Calculate call option value for each drug using the model
print("\n")
print("Phase 2")
for i, drug in enumerate(drugs_phase2):
    call_option_price = binomial_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma'], n
    )

    print(f"Binomial price for Drug {i + 1}: ${call_option_price:.2f}")

#################################################################################
# Parameters for drug portfolio 3
drugs_phase3= [
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.2483},
    {'S': 3939.82, 'K': 44.18, 'T': 10, 'r': 0.03879, 'sigma': 0.175},
    {'S': 1040.76, 'K': 11.67, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 437.45, 'K': 4.90, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 2053.78, 'K': 23.03, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 4154.43, 'K': 46.58, 'T': 10, 'r': 0.03879, 'sigma': 0.125},
    {'S': 1721.95, 'K': 19.31, 'T': 10, 'r': 0.03879, 'sigma': 0.2483}]

# Calculate call option value for each drug using the model
print("\n")
print("Phase 3")
for i, drug in enumerate(drugs_phase3):
    call_option_price = binomial_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma'], n
    )
    print(f"Binomial price for Drug {i + 1}: ${call_option_price:.2f}")

#################################################################################
# Parameters for drug portfolio 4
print("\n")
print("Phase 4")
drugs_phase4= [
    {'S': 141.88, 'K': 0.31, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 2328.62, 'K': 5.07, 'T': 10, 'r': 0.03879, 'sigma': 0.15},
    {'S': 1659.55, 'K': 3.62 ,'T': 10, 'r': 0.03879, 'sigma': 0.15}]

# Calculate call option value for each drug using the model
for i, drug in enumerate(drugs_phase4):
    call_option_price = binomial_option_pricing(
        drug['S'], drug['K'], drug['T'], drug['r'], drug['sigma'], n
    )
    print(f"Binomial price for Drug {i + 1}: ${call_option_price:.2f}")
# Out:
# Phase 1
# Binomial price for Drug: 1: $347.21
# Binomial price for Drug: 2: $347.21
# Binomial price for Drug: 3: $109.61
# Binomial price for Drug: 4: $83.85
# Binomial price for Drug: 5: $109.61
# Binomial price for Drug: 6: $135.25
# Binomial price for Drug: 7: $366.13
# Binomial price for Drug: 8: $151.75
# Binomial price for Drug: 9: $491.86
# Binomial price for Drug: 10: $366.80
#
#
# Phase 2
# Binomial price for Drug 1: $203.45
# Binomial price for Drug 2: $96.41
# Binomial price for Drug 3: $220.77
# Binomial price for Drug 4: $217.22
# Binomial price for Drug 5: $253.46
# Binomial price for Drug 6: $253.46
# Binomial price for Drug 7: $174.94
#
#
# Phase 3
# Binomial price for Drug 1: $4122.83
# Binomial price for Drug 2: $4122.83
# Binomial price for Drug 3: $4122.83
# Binomial price for Drug 4: $3909.84
# Binomial price for Drug 5: $1032.84
# Binomial price for Drug 6: $434.13
# Binomial price for Drug 7: $4122.83
# Binomial price for Drug 8: $2038.15
# Binomial price for Drug 9: $4122.83
# Binomial price for Drug 10: $1708.85
#
#
# Phase 4
# Binomial price for Drug 1: $141.67
# Binomial price for Drug 2: $2325.18
# Binomial price for Drug 3: $1657.09
